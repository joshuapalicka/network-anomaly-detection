# %%
import pandas as pd
from turtleIsolationForests.extendedIsolationForest import ExtendedIsolationForest
from turtleIsolationForests.printResults import notebook_visual_printout, csv_printout
from turtleIsolationForests.preprocessFeatures import preprocess_features

# %%
train_dataframe = pd.read_csv("./eda_simple_classification/network_data_mod_train.csv", index_col=0)
test_dataframe = pd.read_csv("./eda_simple_classification/network_data_mod_test.csv", index_col=0)
X_train, X_test, train_labels, test_labels = preprocess_features(train_dataframe, test_dataframe)
contamination = sum(train_labels) / len(train_labels)
contamination
# Out:
# 0.4654171925730117

# %%
model = ExtendedIsolationForest(contamination = contamination, random_state = None)
#notebook_visual_printout(X_train, X_test, train_labels, test_labels, model)
csv_printout(20, X_train, X_test, train_labels, test_labels, model)
# Out:
# run,precision,recall,f1,auroc,test_predict_time
# 0,0.8504885444743935,0.7867996571339515,0.8174053835256021,0.8758887478134451,16.9760479927063
# 1,0.8890629078569564,0.7962284734668433,0.8400887938830881,0.875834122303832,17.19101858139038
# 2,0.893985818086317,0.7957609288552949,0.842018469656992,0.8569986969238147,17.035974979400635
# 3,0.8805079044735957,0.8159432712537988,0.8469969666329626,0.8769559252500916,17.269757509231567
# 4,0.8812734721748037,0.804566352372789,0.8411747932706017,0.8767647219238984,17.482826471328735
# 5,0.9223419203747073,0.7672407075508455,0.8376722817764166,0.9022559737658895,17.419872999191284
# 6,0.9160014850566178,0.7690329618951142,0.836107934087347,0.8653410614206342,17.526150703430176
# 7,0.9105376730803812,0.7891373801916933,0.8455019828845753,0.885978590988923,18.05007553100586
# 8,0.9184888806178468,0.7691888100989636,0.8372349448685327,0.9102456857623084,18.62639570236206
# 9,0.9061855670103093,0.7534481415101691,0.8227885801812534,0.8746126293070869,17.44183850288391
# 10,0.8987240117783528,0.7848515545858334,0.8379367720465891,0.8619922950066715,15.2175452709198
# 11,0.9097890451517394,0.766227694225824,0.831859904403367,0.8805368992288257,15.664428234100342
# 12,0.9130117625604085,0.7802540325722747,0.8414285714285715,0.8949243276406209,15.49417495727539
# 13,0.8900795022468027,0.8026182498246708,0.8440893259577956,0.897627297357755,15.58563756942749
# 14,0.811310234966149,0.7937349022052521,0.8024263431542461,0.8345082772913318,15.062370538711548
# 15,0.9059813912272928,0.7966960180783916,0.8478314951488515,0.8813114460250655,15.759934663772583
