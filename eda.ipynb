# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_loc = "ServerMachineDataset/test/"
a1 = "machine-1-1.txt"

df_columns = list(range(38))
df = pd.read_csv(data_loc + a1, names=df_columns)

# %%
df.describe()
# Out:
#                  0             1             2             3        4   \
# count  28479.000000  28479.000000  28479.000000  28479.000000  28479.0
# mean       0.145166      0.108322      0.107874      0.106855      0.0
# std        0.136204      0.102157      0.102078      0.103836      0.0
# min        0.010753      0.000000      0.002230      0.001161      0.0
# 25%        0.064516      0.047669      0.050167      0.048780      0.0
# 50%        0.096774      0.079449      0.080268      0.080139      0.0
# 75%        0.161290      0.131356      0.120401      0.117305      0.0
# max        1.000000      1.000000      1.000000      1.000000      0.0
#
#                  5             6        7             8             9   ...  \
# count  28479.000000  28479.000000  28479.0  28479.000000  28479.000000  ...
# mean       0.915816      0.254842      0.0      0.023751      0.001014  ...
# std        0.030684      0.072073      0.0      0.019688      0.015724  ...
# ...

# %%
plt.plot(df[0])

# %%
plt.plot(df[1])
