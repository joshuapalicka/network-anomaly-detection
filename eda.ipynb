# %% [markdown]
# ### Load data from datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_loc = "KDD/"
a1 = "KDDTrain+.txt"

import csv
file = open("KDD/labels.txt", "r")
data = list(csv.reader(file, delimiter=","))
data = data[0]

df_columns = pd.read_csv("KDD/labels.txt")
df = pd.read_csv(data_loc + a1, names=data)

#df_labels_columns = [0]
#df_labels = pd.read_csv("ServerMachineDataset/test_label/machine-1-1.txt")

# %% [markdown]
# ### Data imported, time to analyze

# %%
df.describe()
# Out:
#             KDDTest          flag     src_bytes      dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198       0.022687
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086       0.253530
# min         0.00000  0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000       3.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.000111       0.204409       0.001222           0.395736
# ...

# %%
df.head()
# Out:
#    KDDTest duration protocol_type service  flag  src_bytes  dst_bytes  land  \
# 0        0      tcp      ftp_data      SF   491          0          0     0
# 1        0      udp         other      SF   146          0          0     0
# 2        0      tcp       private      S0     0          0          0     0
# 3        0      tcp          http      SF   232       8153          0     0
# 4        0      tcp          http      SF   199        420          0     0
#
#    wrong_fragment  urgent  ...  dst_host_srv_count  dst_host_same_srv_rate  \
# 0               0       0  ...                0.17                    0.03
# 1               0       0  ...                0.00                    0.60
# 2               0       0  ...                0.10                    0.05
# 3               0       0  ...                1.00                    0.00
# 4               0       0  ...                1.00                    0.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# ...

# %% [markdown]
# In the following plots, we can see that the data is very spread out but stays within 0 to 1. We're still looking for labels for this data.

# %%
plt.plot(df[0])

# %%
plt.plot(df[1])

# %%
plt.plot(df_labels)

# %%
df_labels.iloc[24379:] = 0

# %%
plt.plot(df[0])
plt.plot(df_labels)
